# %% [markdown]
# <a href="https://colab.research.google.com/github/KamaTsai/2025_05_03_python/blob/main/lesson12/lesson12_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - https://www.perplexity.ai/search/88657a74-a8c6-49a9-b9cf-0884a64ac45d

# %%
# %pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\user\miniconda3\envs\kamatsai\lib\site-packages (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#下載中文字型
import wget
wget.download("https://github.com/roberthsu2003/machine_learning/raw/refs/heads/main/source_data/ChineseFont.ttf")
# Out:
# 'ChineseFont (1).ttf'

# %%
import matplotlib as mpl
from matplotlib.font_manager import fontManager

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font', family="ChineseFont")

# %%
## 用實體的方法產生表格
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
#print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)
figure, axes = plt.subplots()
axes.plot(t, y1, marker="*", linestyle="", label="90")
axes.plot(t, y2, marker="s", linestyle="", label="0")
axes.plot(t, y3, marker="^", linestyle="", label="90")
axes.legend(loc = "upper right", bbox_to_anchor=(1.18,1))
axes.set_title("sin()的正弦波")
axes.set_xlabel("圓周率")
axes.set_ylabel("正弦波值")
plt.show()

# %%
## 用plt (Modual) 的function產生表格
## 簡易寫法
## 如果沒有Figure, 幫我建一個figure
## 如果有Figure, 就用這個Figure
## 如果沒有Axes, 幫我建一個Axes,
## 如果有Axes, 就用這個Axes,
import math
import numpy as np
from numpy import ndarray
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

t:ndarray = np.arange(0, 2.5, 0.1)
# t.ndim
# t.size
# t.shape
# t.dtype
#print(t)
y1:ndarray = np.sin(t * math.pi)
y2:ndarray = np.sin(t * math.pi + math.pi/2)
y3:ndarray = np.sin(t * math.pi - math.pi/2)

plt.plot(t, y1, marker="*", linestyle="", label="90")
plt.plot(t, y2, marker="s", linestyle="", label="0")
plt.plot(t, y3, marker="^", linestyle="", label="90")
plt.legend(loc = "upper right", bbox_to_anchor=(1.18,1))
plt.title("sin()的正弦波")
plt.xlabel("圓周率")
plt.ylabel("正弦波值")
plt.show()
# Out:
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27491 (\N{CJK UNIFIED IDEOGRAPH-6B63}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24358 (\N{CJK UNIFIED IDEOGRAPH-5F26}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27874 (\N{CJK UNIFIED IDEOGRAPH-6CE2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 22291 (\N{CJK UNIFIED IDEOGRAPH-5713}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21608 (\N{CJK UNIFIED IDEOGRAPH-5468}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\User\miniconda3\envs\KamaTsai\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
